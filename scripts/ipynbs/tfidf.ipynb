# %%
import gensim.downloader as api
from gensim.models import TfidfModel
from gensim.corpora import Dictionary
# Out:
# Collecting gensim
#   Using cached gensim-4.3.0.tar.gz (23.3 MB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy>=1.18.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gensim->-r requirements.txt (line 1)) (1.24.2)
# Requirement already satisfied: scipy>=1.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gensim->-r requirements.txt (line 1)) (1.10.0)
# Requirement already satisfied: smart_open>=1.8.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gensim->-r requirements.txt (line 1)) (6.3.0)
# Requirement already satisfied: FuzzyTM>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from gensim->-r requirements.txt (line 1)) (2.0.5)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from FuzzyTM>=0.4.0->gensim->-r requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: pyfume in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from FuzzyTM>=0.4.0->gensim->-r requirements.txt (line 1)) (0.2.25)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->FuzzyTM>=0.4.0->gensim->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pandas->FuzzyTM>=0.4.0->gensim->-r requirements.txt (line 1)) (2022.7.1)
# Requirement already satisfied: simpful in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim->-r requirements.txt (line 1)) (2.9.0)
# Requirement already satisfied: fst-pso in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from pyfume->FuzzyTM>=0.4.0->gensim->-r requirements.txt (line 1)) (1.8.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas->FuzzyTM>=0.4.0->gensim->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: miniful in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from fst-pso->pyfume->FuzzyTM>=0.4.0->gensim->-r requirements.txt (line 1)) (0.0.6)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from simpful->pyfume->FuzzyTM>=0.4.0->gensim->-r requirements.txt (line 1)) (2.28.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim->-r requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim->-r requirements.txt (line 1)) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim->-r requirements.txt (line 1)) (1.26.14)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests->simpful->pyfume->FuzzyTM>=0.4.0->gensim->-r requirements.txt (line 1)) (2022.12.7)
# Building wheels for collected packages: gensim
#   Building wheel for gensim (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [525 lines of output]
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib.macosx-10.9-universal2-cpython-311
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim
#       copying gensim/interfaces.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim
#       copying gensim/downloader.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim
#       copying gensim/matutils.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim
#       copying gensim/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim
#       copying gensim/utils.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim
#       copying gensim/nosy.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim/similarities
#       copying gensim/similarities/docsim.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/similarities
#       copying gensim/similarities/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/similarities
#       copying gensim/similarities/nmslib.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/similarities
#       copying gensim/similarities/levenshtein.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/similarities
#       copying gensim/similarities/termsim.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/similarities
#       copying gensim/similarities/annoy.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/similarities
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_text_analysis.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_glove2word2vec.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_parsing.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_tmdiff.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_utils.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_matutils.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_word2vec.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_segmentation.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_lsimodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_coherencemodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_miislita.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_phrases.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_tfidfmodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_poincare.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_rpmodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_corpora_hashdictionary.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_ensemblelda.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/simspeed2.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_aggregation.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_lee.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_big.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_translation_matrix.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/basetmtests.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_ldaseqmodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_datatype.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_similarity_metrics.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_ldamodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_nmf.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_lda_callback.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/utils.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_keyedvectors.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_corpora_dictionary.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/svd_error.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_logentropy_model.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_doc2vec.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_similarities.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_direct_confirmation.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_api.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_atmodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_corpora.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_indirect_confirmation.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_probability_estimation.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_fasttext.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_bm25model.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_scripts.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_normmodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_hdpmodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/test_sharded_corpus.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       copying gensim/test/simspeed.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/poincare.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/basemodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/phrases.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/ensemblelda.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/_fasttext_bin.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/word2vec.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/normmodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/flsamodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/translation_matrix.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/bm25model.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/lsimodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/rpmodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/logentropy_model.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/keyedvectors.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/lda_worker.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/fasttext.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/tfidfmodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/doc2vec.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/callbacks.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/hdpmodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/ldamulticore.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/ldaseqmodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/lsi_dispatcher.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/lda_dispatcher.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/ldamodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/nmf.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/atmodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/lsi_worker.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/coherencemodel.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim/scripts
#       copying gensim/scripts/make_wikicorpus.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/scripts
#       copying gensim/scripts/word2vec2tensor.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/scripts
#       copying gensim/scripts/package_info.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/scripts
#       copying gensim/scripts/benchmark.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/scripts
#       copying gensim/scripts/segment_wiki.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/scripts
#       copying gensim/scripts/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/scripts
#       copying gensim/scripts/make_wiki_online.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/scripts
#       copying gensim/scripts/make_wiki.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/scripts
#       copying gensim/scripts/make_wiki_online_nodebug.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/scripts
#       copying gensim/scripts/glove2word2vec.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/scripts
#       copying gensim/scripts/word2vec_standalone.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/scripts
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim/parsing
#       copying gensim/parsing/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/parsing
#       copying gensim/parsing/preprocessing.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/parsing
#       copying gensim/parsing/porter.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/parsing
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim/topic_coherence
#       copying gensim/topic_coherence/direct_confirmation_measure.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/topic_coherence
#       copying gensim/topic_coherence/aggregation.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/topic_coherence
#       copying gensim/topic_coherence/text_analysis.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/topic_coherence
#       copying gensim/topic_coherence/probability_estimation.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/topic_coherence
#       copying gensim/topic_coherence/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/topic_coherence
#       copying gensim/topic_coherence/indirect_confirmation_measure.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/topic_coherence
#       copying gensim/topic_coherence/segmentation.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/topic_coherence
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/sharded_corpus.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/textcorpus.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/wikicorpus.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/csvcorpus.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/opinosiscorpus.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/__init__.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/malletcorpus.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/mmcorpus.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/ucicorpus.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/indexedcorpus.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/lowcorpus.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/bleicorpus.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/dictionary.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/svmlightcorpus.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/hashdictionary.py -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       running egg_info
#       writing gensim.egg-info/PKG-INFO
#       writing dependency_links to gensim.egg-info/dependency_links.txt
#       writing requirements to gensim.egg-info/requires.txt
#       writing top-level names to gensim.egg-info/top_level.txt
#       reading manifest file 'gensim.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       adding license file 'COPYING'
#       writing manifest file 'gensim.egg-info/SOURCES.txt'
#       /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'gensim.test.test_data' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'gensim.test.test_data' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'gensim.test.test_data' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'gensim.test.test_data' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'gensim.test.test_data.DTM' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'gensim.test.test_data.DTM' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'gensim.test.test_data.DTM' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'gensim.test.test_data.DTM' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'gensim.test.test_data.PathLineSentences' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'gensim.test.test_data.PathLineSentences' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'gensim.test.test_data.PathLineSentences' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'gensim.test.test_data.PathLineSentences' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'gensim.test.test_data.old_d2v_models' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'gensim.test.test_data.old_d2v_models' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'gensim.test.test_data.old_d2v_models' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'gensim.test.test_data.old_d2v_models' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/setuptools/command/build_py.py:202: SetuptoolsDeprecationWarning:     Installing 'gensim.test.test_data.old_w2v_models' as data is deprecated, please list it in `packages`.
#           !!
#
#
#           ############################
#           # Package would be ignored #
#           ############################
#           Python recognizes 'gensim.test.test_data.old_w2v_models' as an importable package,
#           but it is not listed in the `packages` configuration of setuptools.
#
#           'gensim.test.test_data.old_w2v_models' has been automatically added to the distribution only
#           because it may contain data files, but this behavior is likely to change
#           in future versions of setuptools (and therefore is considered deprecated).
#
#           Please make sure that 'gensim.test.test_data.old_w2v_models' is included as a package by using
#           the `packages` configuration field or the proper discovery methods
#           (for example by using `find_namespace_packages(...)`/`find_namespace:`
#           instead of `find_packages(...)`/`find:`).
#
#           You can read more about "package discovery" and "data files" on setuptools
#           documentation page.
#
#
#       !!
#
#         check.warn(importable)
#       copying gensim/_matutils.c -> build/lib.macosx-10.9-universal2-cpython-311/gensim
#       copying gensim/_matutils.pyx -> build/lib.macosx-10.9-universal2-cpython-311/gensim
#       copying gensim/similarities/fastss.c -> build/lib.macosx-10.9-universal2-cpython-311/gensim/similarities
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/EN.1-10.cbow1_wind5_hs0_neg10_size300_smpl1e-05.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/IT.1-10.cbow1_wind5_hs0_neg10_size300_smpl1e-05.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/OPUS_en_it_europarl_train_one2ten.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/alldata-id-10.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/atmodel_3_0_1_model -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/atmodel_3_0_1_model.expElogbeta.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/atmodel_3_0_1_model.id2word -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/atmodel_3_0_1_model.state -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/bgwiki-latest-pages-articles-shortened.xml.bz2 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/compatible-hash-true.model -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/cp852_fasttext.bin -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/crime-and-punishment.bin -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/crime-and-punishment.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/crime-and-punishment.vec -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/d2v-lee-v0.13.0 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/doc2vec_old -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/doc2vec_old_sep -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/doc2vec_old_sep.syn0_lockf.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/doc2vec_old_sep.syn1neg.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/dtm_test.dict -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/dtm_test.mm -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/ensemblelda -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/enwiki-latest-pages-articles1.xml-p000000010p000030302-shortened.bz2 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/enwiki-table-markup.xml.bz2 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/euclidean_vectors.bin -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/fasttext_old -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/fasttext_old_sep -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/fasttext_old_sep.syn0_lockf.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/fasttext_old_sep.syn1neg.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/fb-ngrams.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/ft_kv_3.6.0.model.gz -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/ft_model_2.3.0 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/head500.noblanks.cor -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/head500.noblanks.cor.bz2 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/head500.noblanks.cor_tfidf.model -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/head500.noblanks.cor_wordids.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/high_precision.kv.bin -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/high_precision.kv.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/large_tag_doc_10_iter50 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/lda_3_0_1_model -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/lda_3_0_1_model.expElogbeta.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/lda_3_0_1_model.id2word -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/lda_3_0_1_model.state -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_2_7 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_2_7.expElogbeta.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_2_7.id2word -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_2_7.state -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_3_5 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_3_5.expElogbeta.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_3_5.id2word -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/ldamodel_python_3_5.state -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/ldavowpalwabbit.dict.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/ldavowpalwabbit.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/lee.cor -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/lee_background.cor -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/lee_fasttext -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/lee_fasttext.bin -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/lee_fasttext.vec -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/lee_fasttext_new.bin -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/miIslita.cor -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/mini_newsgroup -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/model-from-gensim-3.8.0.w2v -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/nmf_model -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/non_ascii_fasttext.bin -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/old_keyedvectors_320.dat -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/pang_lee_polarity.cor -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/pang_lee_polarity_fasttext.bin -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/pang_lee_polarity_fasttext.vec -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/para2para_text1.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/para2para_text2.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/phraser-3.6.0.model -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/phraser-no-common-terms.pkl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/phraser-no-scoring.pkl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/phraser-scoring-str.pkl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/phrases-3.6.0.model -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/phrases-no-common-terms.pkl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/phrases-no-scoring.pkl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/phrases-scoring-str.pkl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/poincare_cp852.tsv -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/poincare_hypernyms.tsv -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/poincare_hypernyms_large.tsv -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/poincare_test_3.4.0 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/poincare_utf8.tsv -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/poincare_vectors.bin -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/pre_0_13_2_model -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/pre_0_13_2_model.state -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/pretrained.vec -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/questions-words.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/reproduce.dat -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/reproduce.dat.gz -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/similarities0-1.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/simlex999.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/small_tag_doc_5_iter50 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/test_corpus_ok.mm -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/test_corpus_small.mm -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/test_glove.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_corrupt.mm -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_no_index.mm -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_no_index.mm.bz2 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_no_index.mm.gz -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_overflow.mm -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_with_index.mm -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/test_mmcorpus_with_index.mm.index -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.blei -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.blei.index -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.blei.vocab -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.low -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.low.index -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.mallet -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.mallet.index -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.mm -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.mm.index -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.svmlight -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.svmlight.index -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.uci -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.uci.index -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.uci.vocab -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/testcorpus.xml.bz2 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/tfidf_model.tst -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/tfidf_model.tst.bz2 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/tfidf_model_3_2.tst -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/toy-data.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/toy-model-pretrained.bin -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/toy-model.bin -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/toy-model.vec -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/varembed_lee_subcorpus.cor -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/varembed_morfessor.bin -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/varembed_vectors.pkl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/w2v-lee-v0.12.0 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/w2v_keyedvectors_load_test.modeldata -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/w2v_keyedvectors_load_test.vocab -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_3.3 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old_sep -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old_sep.syn0_lockf.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old_sep.syn1neg.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_c -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_py2 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_py3 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_py3_4 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.neg_labels.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.syn0.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.syn0_lockf.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.syn1neg.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.neg_labels.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.syn0.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.syn0_lockf.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.syn1neg.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.neg_labels.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.syn0.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.syn0_lockf.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.syn1neg.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/wordsim353.tsv -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/DTM
#       copying gensim/test/test_data/DTM/ldaseq_3_0_1_model -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/DTM
#       copying gensim/test/test_data/DTM/sstats_test.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/DTM
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/PathLineSentences
#       copying gensim/test/test_data/PathLineSentences/1.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/PathLineSentences
#       copying gensim/test/test_data/PathLineSentences/2.txt.bz2 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/PathLineSentences
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.1.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.2.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.3.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.4.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.1.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
# ...
#       copying gensim/test/test_data/toy-model-pretrained.bin -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/toy-model.bin -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/toy-model.vec -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/varembed_lee_subcorpus.cor -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/varembed_morfessor.bin -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/varembed_vectors.pkl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/w2v-lee-v0.12.0 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/w2v_keyedvectors_load_test.modeldata -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/w2v_keyedvectors_load_test.vocab -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_3.3 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old_sep -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old_sep.syn0_lockf.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_old_sep.syn1neg.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_c -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_py2 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_py3 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_py3_4 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.neg_labels.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.syn0.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.syn0_lockf.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py2.syn1neg.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.neg_labels.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.syn0.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.syn0_lockf.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3.syn1neg.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.neg_labels.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.syn0.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.syn0_lockf.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/word2vec_pre_kv_sep_py3_4.syn1neg.npy -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       copying gensim/test/test_data/wordsim353.tsv -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/DTM
#       copying gensim/test/test_data/DTM/ldaseq_3_0_1_model -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/DTM
#       copying gensim/test/test_data/DTM/sstats_test.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/DTM
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/PathLineSentences
#       copying gensim/test/test_data/PathLineSentences/1.txt -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/PathLineSentences
#       copying gensim/test/test_data/PathLineSentences/2.txt.bz2 -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/PathLineSentences
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.1.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.2.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.3.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.12.4.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.1.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.2.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.3.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_0.13.4.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_1.0.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_1.0.1.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_2.0.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_2.1.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_2.2.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_2.3.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_3.0.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_3.1.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_3.2.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_3.3.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       copying gensim/test/test_data/old_d2v_models/d2v_3.4.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_d2v_models
#       creating build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.12.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.12.1.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.12.2.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.12.3.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.12.4.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.13.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.13.1.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.13.2.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.13.3.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_0.13.4.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_1.0.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_1.0.1.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_2.0.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_2.1.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_2.2.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_2.3.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_3.0.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_3.1.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_3.2.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_3.3.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/test/test_data/old_w2v_models/w2v_3.4.0.mdl -> build/lib.macosx-10.9-universal2-cpython-311/gensim/test/test_data/old_w2v_models
#       copying gensim/models/doc2vec_corpusfile.cpp -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/doc2vec_corpusfile.pyx -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/doc2vec_inner.cpp -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/doc2vec_inner.pxd -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/doc2vec_inner.pyx -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/fast_line_sentence.h -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/fasttext_corpusfile.cpp -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/fasttext_corpusfile.pyx -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/fasttext_inner.c -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/fasttext_inner.pxd -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/fasttext_inner.pyx -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/nmf_pgd.c -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/nmf_pgd.pyx -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/stdint_wrapper.h -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/voidptr.h -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/word2vec_corpusfile.cpp -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/word2vec_corpusfile.pxd -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/word2vec_corpusfile.pyx -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/word2vec_inner.c -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/word2vec_inner.pxd -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/models/word2vec_inner.pyx -> build/lib.macosx-10.9-universal2-cpython-311/gensim/models
#       copying gensim/corpora/_mmreader.c -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       copying gensim/corpora/_mmreader.pyx -> build/lib.macosx-10.9-universal2-cpython-311/gensim/corpora
#       running build_ext
#       building 'gensim.models.word2vec_inner' extension
#       creating build/temp.macosx-10.9-universal2-cpython-311
#       creating build/temp.macosx-10.9-universal2-cpython-311/gensim
#       creating build/temp.macosx-10.9-universal2-cpython-311/gensim/models
#       clang -Wsign-compare -Wunreachable-code -fno-common -dynamic -DNDEBUG -g -fwrapv -O3 -Wall -arch arm64 -arch x86_64 -g -I/Library/Frameworks/Python.framework/Versions/3.11/include/python3.11 -I/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/numpy/core/include -c gensim/models/word2vec_inner.c -o build/temp.macosx-10.9-universal2-cpython-311/gensim/models/word2vec_inner.o
#       gensim/models/word2vec_inner.c:217:12: fatal error: 'longintrepr.h' file not found
#         #include "longintrepr.h"
#                  ^~~~~~~~~~~~~~~
#       1 error generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# × Encountered error while trying to install package.
# ╰─> gensim
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 get_ipython().system('pip3 install -r requirements.txt')
# ----> 2 import gensim.downloader as api
#       3 from gensim.models import TfidfModel
#       4 from gensim.corpora import Dictionary
#
# ModuleNotFoundError: No module named 'gensim'

# %%
# !pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (23.0)
# Collecting pip
#   Downloading pip-23.0.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 7.6 MB/s eta 0:00:0000:0100:01m
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0
#     Uninstalling pip-23.0:
#       Successfully uninstalled pip-23.0
# Successfully installed pip-23.0.1

# %%
dataset = api.load("text8")
dct = Dictionary(dataset)  # fit dictionary
corpus = [dct.doc2bow(line) for line in dataset]  # convert corpus to BoW format

# %%
model = TfidfModel(corpus)  # fit model
vector = model[corpus[0]]  # apply model to the first corpus document

# %%
import os

corpusdir = '/Users/bcritt/Documents/StanfordProjects/Corpora/Emerson/emerson/'
corpus = []
for infile in os.listdir(corpusdir):
    with open(corpusdir+infile, errors='ignore') as fin:
        corpus.append(fin.read())

# %%
import pandas as pd
tfIdfVectorizer=TfidfVectorizer(use_idf=True)
tfIdf = tfIdfVectorizer.fit_transform(corpus)
df = pd.DataFrame(tfIdf[0].T.todense(), index=tfIdfVectorizer.get_feature_names_out(), columns=["TF-IDF"])
df = df.sort_values('TF-IDF', ascending=False)
print (df.head(25))
# Out:
#           TF-IDF
# the     0.465956
# and     0.388773
# of      0.371622
# to      0.268711
# he      0.245842
# his     0.237266
# in      0.220114
# was     0.208680
# hoar    0.127345
# him     0.102370
# it      0.091476
# that    0.091476
# had     0.089981
# with    0.077183
# as      0.060031
# on      0.060031
# or      0.057611
# but     0.054314
# which   0.051455
# mr      0.047230
# for     0.045738
# not     0.042879
# squire  0.040652
# no      0.040021
# when    0.037734
